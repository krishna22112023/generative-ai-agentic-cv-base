# %%
import pandas as pd
df = pd.read_parquet("/Users/krishnaiyer/Downloads/test-00000-of-00001-4e9914a0beb5c975.parquet",engine="pyarrow")

# %%
df
# Out:
#      image_id                                              image  width  \
# 0         118  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 1          37  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 2         158  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 3         114  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 4         117  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# ..        ...                                                ...    ...
# 182       185  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 183       128  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 184       167  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 185       101  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
# 186       111  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    640
#
#      height                                            objects
# ...
